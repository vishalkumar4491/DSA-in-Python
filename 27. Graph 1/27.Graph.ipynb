# %%
# Graph

class graph:
    def __init__(self, nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]
        
    def addEdge(self, u, v):
        self.adjMatrix[u][v] = 1
        self.adjMatrix[v][u] = 1
        
    def removeEdge(self, u, v):
        if self.containEdge(u, v) is False:
            return
        self.adjMatrix[u][v] = 0
        self.adjMatrix[v][u] = 0
        
    def containEdge(self, u, v):
        return True if self.adjMatrix[u][v] > 1 else False
    
#  dfs   
#     sv = starting vertex
    def __dfsHelper(self, sv, visited):
        visited[sv] = True
        print(sv, end = ' ')
        for i in range(self.nVertices):
            if self.adjMatrix[sv][i] > 0 and visited[i] is False:
                self.__dfsHelper(i, visited)
    
    def dfs(self):
        visited = [False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i] == False:
                self.__dfsHelper(i, visited)
 

 
    
    
# bfs
    def __bfsHelper(self, sv, visited):
        q = []
        visited[sv] = True
        q.append(sv)
        while(q != []):
            x = q.pop(0)
            print(x, end = ' ')
            for i in range(self.nVertices):
                if self.adjMatrix[x][i] > 0 and visited[i] is False:
                    q.append(i)
                    visited[i] = True
          
    def bfs(self):
        visited = [False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i] == False:
                self.__bfsHelper(i, visited)
                
     
 
#     ev = ending vertex
    def __hasPathHelper(self, sv, visited, ev):
        if self.adjMatrix[sv][ev] > 0:
            return True
        visited[sv] = True
        for i in range(self.nVertices):
            if self.adjMatrix[sv][i] > 0 and visited[i] == False:
                if self.__hasPathHelper(i, visited, ev):
                    return True
        return False
    
    def hasPath(self, u, v):
        visited = [False for i in range(self.nVertices)]
        if visited[u] == False:
            return self.__hasPathHelper(u, visited, v)
    
 

# get path
    def __getPathHelper(self, sv, ev, visited, li):
        if self.adjMatrix[sv][ev] > 0:
            li.append(ev)
            li.append(sv)
            return li 
        visited[sv] = True
        for i in range(self.nVertices):
            if self.adjMatrix[sv][i] > 0 and visited[i] == False:
                if self.__getPathHelper(i,ev, visited, li):
                    li.append(sv)
                    return li
        return False
        
    def getPath(self, u, v):
        visited = [False for i in range(self.nVertices)]
        if visited[u] == False:
            li = []
            return self.__getPathHelper(u, v, visited, li)

        
#  get path using bfs or shortest path till that point

    def shortestPath(self, u, v):
        visited = [False for i in range(self.nVertices)]
        
        parent = {}
        li = []
        li.append(u)
        visited[u] = True
        z = 0
        while(li):
            if z == 1:
                break
            x = li.pop(0)
            for i in range(self.nVertices):
                if self.adjMatrix[x][i] > 0 and visited[i] == False:
                    li.append(i)
                    visited[i] = True
                    parent[i] = x
                    if self.adjMatrix[x][i] > 0 and i == v:
                        z = 1
                        break      
        res = []
        y = v
        res.append(v)
        while(v != u):
            res.append(parent[v])
            v = parent[v]
            
        return res
            

        
# graph is connected or not
    def __isConnectedHelper(self, visited, u):
        visited[u] = True
        for i in range(self.nVertices):
            if visited[i] == False and self.adjMatrix[u][i] > 0:
                self.__isConnectedHelper(visited, i)
        for i in range(self.nVertices):
            if visited[i] == False:
                return False
        return True
        
    def isConnected(self):
        visited = [False for i in range(self.nVertices)]
        return self.__isConnectedHelper(visited, 0)
        

        
        
# return the graph which are connected    
    def __connectedHelper(self, u, visited, li):
        visited[u] = True
        li.append(u)
        for i in range(self.nVertices):
            if visited[i] == False and self.adjMatrix[u][i] > 0:
                self.__connectedHelper(i, visited, li)
        return li
    
    def connected(self):
        visited = [False for i in range(self.nVertices)]
        li = []
        for i in range(self.nVertices):
           
            if visited[i] == False:
                a = []
                self.__connectedHelper(i, visited, a)
                li.append(a)
        return li

        
g = graph(8)
# g.addEdge(0, 2)
# g.addEdge(0, 1)

# g.addEdge(0, 3)
# g.addEdge(1, 5)
# g.addEdge(0, 1)
# g.addEdge(1, 4)
# g.addEdge(2, 6)
# g.addEdge(8, 3)
# g.addEdge(2, 7)
# g.addEdge(6, 9)
# g.addEdge(5, 6)
# g.addEdge(5, 9)
g.addEdge(0, 7)
g.addEdge(1, 4)
g.addEdge(1, 2)
g.addEdge(5, 3)
g.addEdge(3, 6)
# g.dfs()
# print()
# g.bfs()
# print()
# print(g.hasPath(5, 4))
# print(g.getPath(0, 6))

# print(g.shortestPath(0, 9))
print(g.isConnected())
print(g.connected())
# Out:
# False
# [[0, 7], [1, 2, 4], [3, 5, 6]]
